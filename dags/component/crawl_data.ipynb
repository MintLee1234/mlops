# %%
import pandas as pd 
import numpy as np
import datetime

# %%
df = pd.read_csv('/home/minhle/mlops/data/web_churn_raw.csv')
df.drop_duplicates(inplace=True)
len(df)
# Out:
# 36992

# %%
weekday_number = datetime.date.today().weekday()
splits = np.array_split(df, 7)
today_split = splits[1]
# Out:
# /home/minhle/miniconda3/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
df1 = pd.read_csv('/home/minhle/mlops/data/data_crawl.csv')
len(df1)
# Out:
# 5286

# %%
df1 = pd.concat([df1, today_split], ignore_index=True)
df1
# Out:
#                user_id  age gender region_category  membership_category  \
# 0     9a676d9b38bd43c2   32      M            Town        No Membership
# 1     8a7dfc54e41b8346   16      M            Town     Basic Membership
# 2     b1a11dc684c79897   24      M            City   Premium Membership
# 3     94e66f59ceca3e60   20      M            City  Platinum Membership
# 4     8d76ac278c712d16   37      M            Town     Basic Membership
# ...                ...  ...    ...             ...                  ...
# 5282  8b4ea240063892f3   36      F            Town     Basic Membership
# 5283  81fc8d1a410a6a70   37      F            Town    Silver Membership
# 5284  ad73c7ad02f3ec26   31      M            Town        No Membership
# 5285  9b52d32f1955f497   58      F            Town     Basic Membership
# 5286  a461c2610b9504f7   13      M            City        No Membership
#
#      joining_date joined_through_referral     preferred_offer_types  \
# ...
