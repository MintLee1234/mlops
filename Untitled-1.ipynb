# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/home/minhle/mlops/data/web_churn_raw.csv')

# %%
df_gold = df[df['joining_date'] <= '2025-03-31']

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from dags.component.data_transform import DataTransformation
import pandas as pd
import datetime as dt
import mlflow
import os
import joblib

# %%
def save_csv_append_or_create(df, path):
    df.to_csv(path, mode='a' if os.path.exists(path) else 'w', index=False, header=not os.path.exists(path))

def crawl_data(today):
    today_str = today
    df = pd.read_csv('/home/minhle/mlops/data/web_churn_raw.csv')
    df = df[df['joining_date'] == today_str].drop(columns=['churn_risk_score'], errors='ignore')
    save_csv_append_or_create(df, '/home/minhle/mlops/data/bronze_data.csv')
    print("✅ Crawled data successfully")

def transform_data(today):
    today_str = today
    df = pd.read_csv('/home/minhle/mlops/data/bronze_data.csv')
    df_today = df[df['joining_date'] == today_str]
    
    if len(df_today) == 0:
        print("⚠️ Không có dữ liệu để transform.")
        return
    
    transformer = DataTransformation()
    silver_df = transformer.transform_data(df_today)
    silver_df['churn_risk_score'] = pd.NA
    save_csv_append_or_create(silver_df, '/home/minhle/mlops/data/silver_data.csv')

    print("✅ Transform data successfully")
    print(silver_df.head())

def daily_prediction(today):
    today_str = today
    df = pd.read_csv('/home/minhle/mlops/data/silver_data.csv')
    df_today = df[df['joining_date'] == today_str]
    
    if len(df_today) == 0:
        print("⚠️ Không có dữ liệu người dùng mới cho hôm nay.")
        return

    user_id = df_today['user_id'].reset_index(drop=True)
    joining_date = df_today['joining_date'].reset_index(drop=True)
    df_today = df_today.drop(columns=['user_id', 'churn_risk_score'], errors='ignore')

    try:
        with open('preprocessors/preprocessor_versions.txt') as f:
            preprocessor_path = f.readlines()[-1].strip().split(' - ')[-1]
        preprocessor = joblib.load(preprocessor_path)
    except Exception as e:
        print(f"❌ Lỗi load preprocessor: {e}")
        return

    try:
        with open('/home/minhle/mlops/last_best_run_id.txt') as f:
            model_id = f.readlines()[-1].strip().split(' - ')[-1]
        model = mlflow.pyfunc.load_model(f"runs:/{model_id}/model")
    except Exception as e:
        print(f"❌ Lỗi load model từ MLflow: {e}")
        return

    df_transformed = preprocessor.transform(df_today)
    predictions = model.predict(df_transformed)

    results = pd.DataFrame({
        'user_id': user_id,
        'joining_date': joining_date,
        'prediction': predictions
    })

    save_csv_append_or_create(results, '/home/minhle/mlops/data/predictions.csv')
    print("✅ Daily prediction completed successfully")

# %%
for i in range (1,31):
    if i < 10: today = f'2025-04-0{i}'
    else: today = f'2025-04-{i}'
    print(type(today))
    crawl_data(today)
    transform_data(i)
    daily_prediction(i)
# Out:
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.
# <class 'str'>
# ✅ Crawled data successfully
# ⚠️ Không có dữ liệu để transform.
# ⚠️ Không có dữ liệu người dùng mới cho hôm nay.

# %%
today_str = '2025-04-01'
df = pd.read_csv('/home/minhle/mlops/data/silver_data.csv')
df_today = df[df['joining_date'] == today_str]
df_today
# Out:
#       age gender region_category  membership_category joining_date  \
# 476  30.0      M            Town  Platinum Membership   2025-04-01
# 477  27.0      F            Town     Basic Membership   2025-04-01
# 478  35.0      F            City    Silver Membership   2025-04-01
# 479  60.0      F            Town     Basic Membership   2025-04-01
# 480  27.0      F            City   Premium Membership   2025-04-01
# ..    ...    ...             ...                  ...          ...
# 961  60.0      F            City     Basic Membership   2025-04-01
# 962  23.0      M            City    Silver Membership   2025-04-01
# 963  61.0      M            Town   Premium Membership   2025-04-01
# 964  57.0      F            Town  Platinum Membership   2025-04-01
# 965  28.0      M            City        No Membership   2025-04-01
#
#     joined_through_referral     preferred_offer_types medium_of_operation  \
# 476                      No            Without Offers             Desktop
# 477                     Yes     Gift Vouchers/Coupons             Desktop
# 478                      No  Credit/Debit Card Offers             Desktop
# 479                     Yes  Credit/Debit Card Offers          Smartphone
# 480                      No     Gift Vouchers/Coupons          Smartphone
# ..                      ...                       ...                 ...
# 961                      No  Credit/Debit Card Offers             Desktop
# 962                      No            Without Offers             Desktop
# 963                      No     Gift Vouchers/Coupons             Desktop
# 964                     Yes     Gift Vouchers/Coupons             Desktop
# 965                     Yes            Without Offers             Desktop
#
#     internet_option  recency  avg_time_spent  monetary  frequency  \
# 476     Mobile_Data     22.0           78.44  32884.42        0.0
# 477     Fiber_Optic     15.0          277.58  48599.35       16.0
# 478           Wi-Fi     23.0          290.44  50492.72        9.0
# 479     Mobile_Data      9.0           52.93  33975.93       25.0
# 480           Wi-Fi     14.0           33.32   3758.58       17.0
# ..              ...      ...             ...       ...        ...
# 961     Fiber_Optic      5.0          182.33  13149.63       18.0
# 962           Wi-Fi     25.0           83.14  48979.72        8.0
# 963     Fiber_Optic     20.0           33.63  16374.15        0.0
# 964           Wi-Fi     10.0          113.78  41352.50       11.0
# 965     Mobile_Data     23.0           32.66  42666.23       26.0
#
#      points_in_wallet used_special_discount offer_application_preference  \
# 476        509.813247                    No                          Yes
# 477        655.240000                    No                          Yes
# 478        740.430000                   Yes                          Yes
# 479        696.440000                    No                          Yes
# 480          0.000000                    No                          Yes
# ..                ...                   ...                          ...
# 961        179.806093                    No                          Yes
# 962        739.530000                    No                          Yes
# 963        759.140000                   Yes                           No
# 964        740.850000                    No                          Yes
# 965        567.240000                    No                          Yes
#
#     past_complaint          complaint_status               feedback  \
# 476             No            Not Applicable  Poor Customer Service
# 477             No            Not Applicable           Poor Website
# 478            Yes  No Information Available  Quality Customer Care
# 479             No            Not Applicable           Poor Website
# 480             No            Not Applicable           Poor Website
# ..             ...                       ...                    ...
# 961             No            Not Applicable  Poor Customer Service
# 962             No            Not Applicable  Poor Customer Service
# 963            Yes  No Information Available           Poor Website
# 964            Yes                  Unsolved  Poor Customer Service
# 965             No            Not Applicable           Too many ads
#
#      tenure_months  visit_hour  login_spend_ratio  login_transaction_ratio  \
# 476            -11          12           0.000000                 0.000000
# 477            -11          21          17.348750                 0.000329
# 478            -11          22          32.271111                 0.000178
# 479            -11          10           2.117200                 0.000736
# 480            -11          13           1.960000                 0.004523
# ..             ...         ...                ...                      ...
# 961            -11          10          10.129444                 0.001369
# 962            -11           8          10.392500                 0.000163
# 963            -11          21           0.000000                 0.000000
# 964            -11          22          10.343636                 0.000266
# 965            -11           9           1.256154                 0.000609
#
#               user_id  churn_risk_score
# 476  8956766f385e2ac1               NaN
# 477  88f0d57d62d2bfe1               NaN
# 478  8e6ad754abe36339               NaN
# 479  873291626d308f97               NaN
# 480  80a5321f0c946f95               NaN
# ..                ...               ...
# 961  b881df9ae17966ca               NaN
# 962  aaab7d7246bbba6c               NaN
# 963  9965f2d539033a19               NaN
# 964  83bf9873a841b9af               NaN
# 965  93d0d550e45931cb               NaN
#
# [490 rows x 25 columns]

# %%
transform_data('2025-04-01')
# Out:
# ✅ Transform data successfully
#       age gender region_category  membership_category joining_date  \
# 238  30.0      M            Town  Platinum Membership   2025-04-01
# 239  27.0      F            Town     Basic Membership   2025-04-01
# 240  35.0      F            City    Silver Membership   2025-04-01
# 241  60.0      F            Town     Basic Membership   2025-04-01
# 242  27.0      F            City   Premium Membership   2025-04-01
#
#     joined_through_referral     preferred_offer_types medium_of_operation  \
# 238                      No            Without Offers             Desktop
# 239                     Yes     Gift Vouchers/Coupons             Desktop
# 240                      No  Credit/Debit Card Offers             Desktop
# 241                     Yes  Credit/Debit Card Offers          Smartphone
# 242                      No     Gift Vouchers/Coupons          Smartphone
#
#     internet_option  recency  avg_time_spent  monetary  frequency  \
# 238     Mobile_Data     22.0           78.44  32884.42        0.0
# 239     Fiber_Optic     15.0          277.58  48599.35       16.0
# 240           Wi-Fi     23.0          290.44  50492.72        9.0
# 241     Mobile_Data      9.0           52.93  33975.93       25.0
# 242           Wi-Fi     14.0           33.32   3758.58       17.0
#
#      points_in_wallet used_special_discount offer_application_preference  \
# 238        509.813247                    No                          Yes
# 239        655.240000                    No                          Yes
# 240        740.430000                   Yes                          Yes
# 241        696.440000                    No                          Yes
# 242          0.000000                    No                          Yes
#
#     past_complaint          complaint_status               feedback  \
# 238             No            Not Applicable  Poor Customer Service
# 239             No            Not Applicable           Poor Website
# 240            Yes  No Information Available  Quality Customer Care
# 241             No            Not Applicable           Poor Website
# 242             No            Not Applicable           Poor Website
#
#      tenure_months  visit_hour  login_spend_ratio  login_transaction_ratio  \
# 238            -11          12           0.000000                 0.000000
# 239            -11          21          17.348750                 0.000329
# 240            -11          22          32.271111                 0.000178
# 241            -11          10           2.117200                 0.000736
# 242            -11          13           1.960000                 0.004523
#
#               user_id churn_risk_score
# 238  8956766f385e2ac1             <NA>
# 239  88f0d57d62d2bfe1             <NA>
# 240  8e6ad754abe36339             <NA>
# 241  873291626d308f97             <NA>
# 242  80a5321f0c946f95             <NA>
