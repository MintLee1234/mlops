# %%
import pymongo
import pandas as pd
import os
import dotenv
import logging
import time
from datetime import datetime

# %%
class DataIngestion:
    def __init__(self, mongo_uri, db_name, collection_name):
        self.mongo_uri = mongo_uri
        self.client = pymongo.MongoClient(self.mongo_uri)
        self.db_name = db_name
        self.collection_name = collection_name
        self.db = self.client[self.db_name]
        self.collection = self.db[self.collection_name]

    def upload_csv_to_mongodb(self, csv_file_path):
        
        df = pd.read_csv(csv_file_path)
        print(f"Loaded {len(df)} records from {csv_file_path}")
        
        data = df.to_dict(orient='records')
        if data:
            self.collection.insert_many(data)
            print(f"Inserted {len(data)} records into {self.db_name}.{self.collection_name}")
        else:
            print("No data to insert.")
        

    def download_data_from_mongodb(self):
        # Lấy toàn bộ documents
        data = list(self.collection.find())

        if not data:
            print("Không có dữ liệu trong collection.")
            return

        # Xoá cột `_id` của MongoDB (tuỳ bạn giữ hay xoá)
        for item in data:
            item.pop('_id', None)

        # Chuyển sang DataFrame
        df = pd.DataFrame(data)
        return df
    
    def delete_all_data(self):
        result = self.collection.delete_many({})
        print(f"Đã xoá {result.deleted_count} documents khỏi {self.db_name}.{self.collection_name}")


        # Đóng kết nối
    def __del__(self):
        self.client.close()
        print("MongoDB connection closed.")

# %%
if __name__ == "__main__":
    # Load environment variables from .env file
    dotenv.load_dotenv()

    mongo_uri = os.getenv("MONGO_URI")
    db_name = os.getenv("DB_NAME")
    collection_name = os.getenv("COLLECTION_NAME")
    csv_file_path = os.getenv("CSV_FILE")

    data_ingestion = DataIngestion(mongo_uri, db_name, collection_name)
    data_ingestion.delete_all_data()  # Xoá dữ liệu cũ nếu cần

    data_ingestion.upload_csv_to_mongodb(csv_file_path)

    df = data_ingestion.download_data_from_mongodb()
    if df is not None:
        print(df.head())
# Out:
# Đã xoá 10000 documents khỏi mlops.root_file
# Loaded 10000 records from D:\Show_me_everything\midterm_mlops\data\Telecom_customer_churn.csv
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File d:\Miniconda\envs\machine_translate\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1162 if buffer is not None:
# -> 1163     return self._sslobj.read(len, buffer)
#    1164 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 13
#      10 data_ingestion = DataIngestion(mongo_uri, db_name, collection_name)
#      11 data_ingestion.delete_all_data()  # Xoá dữ liệu cũ nếu cần
# ---> 13 data_ingestion.upload_csv_to_mongodb(csv_file_path)
#      15 df = data_ingestion.download_data_from_mongodb()
#      16 if df is not None:
#
# Cell In[14], line 17, in DataIngestion.upload_csv_to_mongodb(self, csv_file_path)
#      15 data = df.to_dict(orient='records')
#      16 if data:
# ---> 17     self.collection.insert_many(data)
#      18     print(f"Inserted {len(data)} records into {self.db_name}.{self.collection_name}")
#      19 else:
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:1896, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1882 """Execute an operation with consecutive retries if possible
#    1883
#    1884 Returns func()'s return value on success. On error retries the same
#    (...)
#    1893 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1894 """
#    1895 with self._tmp_session(session) as s:
# -> 1896     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:1782, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1777 # Ensure that the options supports retry_writes and there is a valid session not in
#    1778 # transaction, otherwise, we will not support retry behavior for this txn.
#    1779 retryable = bool(
#    1780     retryable and self.options.retry_writes and session and not session.in_transaction
#    1781 )
# -> 1782 return self._retry_internal(
#    1783     func=func,
#    1784     session=session,
#    1785     bulk=bulk,
#    1786     operation=operation,
#    1787     retryable=retryable,
#    1788     operation_id=operation_id,
#    1789 )
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:2687, in _ClientConnectionRetryable._write(self)
#    2685             self._check_last_error()
#    2686             self._retryable = False
# -> 2687         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2688 except PyMongoError as exc:
#    2689     if not self._retryable:
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\pool.py:622, in Connection.write_command(self, request_id, msg, codec_options)
#     614 """Send "insert" etc. command, returning response as a dict.
#     615
#     616 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     619 :param msg: bytes, the command message.
#     620 """
#     621 self.send_message(msg, 0)
# --> 622 reply = self.receive_message(request_id)
#     623 result = reply.command_response(codec_options)
#     625 # Raises NotPrimaryError or OperationFailure.
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\pool.py:590, in Connection.receive_message(self, request_id)
#     588     return receive_message(self, request_id, self.max_message_size)
#     589 except BaseException as error:
# --> 590     self._raise_connection_failure(error)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\pool.py:588, in Connection.receive_message(self, request_id)
#     583 """Receive a raw BSON message or raise ConnectionFailure.
#     584
#     585 If any exception is raised, the socket is closed.
#     586 """
#     587 try:
# --> 588     return receive_message(self, request_id, self.max_message_size)
#     589 except BaseException as error:
#     590     self._raise_connection_failure(error)
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\network.py:315, in receive_message(conn, request_id, max_message_size)
#     313         deadline = None
#     314 # Ignore the response's request id.
# --> 315 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     316 # No request_id for exhaust cursor "getMore".
#     317 if request_id is not None:
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\network_layer.py:389, in receive_data(conn, length, deadline)
#     386             short_timeout = _POLL_TIMEOUT
#     387         conn.set_conn_timeout(short_timeout)
# --> 389     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     390 except BLOCKING_IO_ERRORS:
#     391     if conn.cancel_context.cancelled:
#
# File d:\Miniconda\envs\machine_translate\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File d:\Miniconda\envs\machine_translate\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#        Customer_ID    rev_Mean    mou_Mean  totmrc_Mean   da_Mean  \
# 0          1867825  299.671415  286.173570    31.476885  0.804606
# 1          3744854   92.584471  363.795294     4.555770  0.713896
# 2          1458591  371.805044  261.054198    20.571977  0.575645
# 3           499914  237.586761  374.034082    20.475378  0.655410
# 4          8478454  463.464125  322.684882    41.554616  0.407415
# ...            ...         ...         ...          ...       ...
# 19995      7271733  157.025824  432.569779    20.847124  0.432566
# 19996       714120  369.972222  287.524120    27.361740  0.049464
# 19997      9115786  249.429742  317.976964    19.561120  0.414199
# 19998      2844739  139.008133  197.331937    14.508734  0.613745
# 19999      8930441  281.091922  288.971795    12.891004  0.398222
#
#        ovrmou_Mean  ovrrev_Mean  vceovr_Mean  datovr_Mean  roam_Mean  ...  \
# 0        45.316933     8.829315    35.792128     6.534869   7.652628  ...
# 1        31.324743    13.921041    13.851242     5.665785   3.096415  ...
# 2        88.676796    10.404854    15.835436     6.715007  13.590641  ...
# 3        70.911423     8.289291    10.739534     3.974069  13.550546  ...
# 4        51.731316     7.035586    13.199957     4.473188   8.596726  ...
# ...            ...          ...          ...          ...        ...  ...
# 19995    13.393915    16.830843    15.784978     6.259984  10.794632  ...
# 19996    72.983420     6.200724    21.492590     6.467971   8.973374  ...
# 19997    58.861880     9.780115    25.808462     6.524170  11.447157  ...
# 19998    33.759629    17.946851    21.232987     2.884560   1.938345  ...
# 19999    56.883831    13.810257    25.371842     2.905337   4.157103  ...
#
#        refurb_new   hnd_price  phones  models  marital  adults        income  \
# 0               R   74.592336       3       1        M       5   81992.93952
# 1               R  186.391656       1       2        M       2   47618.61279
# 2               N   96.455375       2       1        M       5   69649.44830
# 3               N  238.272712       1       1        M       1   68099.63422
# 4               R  133.701343       1       2        D       5  125079.70250
# ...           ...         ...     ...     ...      ...     ...           ...
# 19995           R  143.321136       1       2        M       3   19994.31289
# 19996           R  146.929253       3       2        M       4   68875.63353
# 19997           N  193.081904       2       2        S       1   52935.01142
# 19998           N  123.943428       1       2        S       5   69613.21020
# 19999           N   96.408219       2       2        S       5   63590.51698
#
#        numbcars  ethnic  creditcd
# 0             2       C         Y
# 1             1       A         Y
# 2             1       A         N
# 3             3       A         N
# 4             2       B         Y
# ...         ...     ...       ...
# 19995         1       B         N
# 19996         2       C         N
# 19997         1       C         Y
# 19998         1       C         Y
# 19999         3       A         N
#
# [20000 rows x 84 columns]
