# %%
import pymongo
import pandas as pd
import os
import dotenv
import logging
import time
from datetime import datetime

# %%
class DataIngestion:
    def __init__(self, mongo_uri, db_name, collection_name):
        self.mongo_uri = mongo_uri
        self.client = pymongo.MongoClient(self.mongo_uri)
        self.db_name = db_name
        self.collection_name = collection_name
        self.db = self.client[self.db_name]
        self.collection = self.db[self.collection_name]

    def upload_csv_to_mongodb(self, csv_file_path):
        
        df = pd.read_csv(csv_file_path)
        print(f"Loaded {len(df)} records from {csv_file_path}")
        
        data = df.to_dict(orient='records')
        if data:
            self.collection.insert_many(data)
            print(f"Inserted {len(data)} records into {self.db_name}.{self.collection_name}")
        else:
            print("No data to insert.")
        

    def download_data_from_mongodb(self):
        # Lấy toàn bộ documents
        data = list(self.collection.find())

        if not data:
            print("Không có dữ liệu trong collection.")
            return

        # Xoá cột `_id` của MongoDB (tuỳ bạn giữ hay xoá)
        for item in data:
            item.pop('_id', None)

        # Chuyển sang DataFrame
        df = pd.DataFrame(data)
        return df
    
    def delete_all_data(self):
        result = self.collection.delete_many({})
        print(f"Đã xoá {result.deleted_count} documents khỏi {self.db_name}.{self.collection_name}")


        # Đóng kết nối
    def __del__(self):
        self.client.close()
        print("MongoDB connection closed.")

# %%
if __name__ == "__main__":
    # Load environment variables from .env file
    dotenv.load_dotenv(override=True) 

    mongo_uri = 'mongodb+srv://Minich:Mydatabase.456@minich-data-repository.gzlkk1s.mongodb.net/'
    db_name = 'churn'
    collection_name = 'transformed_web_churn'
    # csv_file_path = os.getenv("CSV_FILE")

    data_ingestion = DataIngestion(mongo_uri, db_name, collection_name)
    # data_ingestion.delete_all_data()  # Xoá dữ liệu cũ nếu cần

    # data_ingestion.upload_csv_to_mongodb(csv_file_path)

    df = data_ingestion.download_data_from_mongodb()
    if df is not None:
        print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[25], line 10
#       7 collection_name = 'transformed_web_churn'
#       8 # csv_file_path = os.getenv("CSV_FILE")
# ---> 10 data_ingestion = DataIngestion(mongo_uri, db_name, collection_name)
#      11 # data_ingestion.delete_all_data()  # Xoá dữ liệu cũ nếu cần
#      12
#      13 # data_ingestion.upload_csv_to_mongodb(csv_file_path)
#      15 df = data_ingestion.download_data_from_mongodb()
#
# Cell In[17], line 4, in DataIngestion.__init__(self, mongo_uri, db_name, collection_name)
#       2 def __init__(self, mongo_uri, db_name, collection_name):
#       3     self.mongo_uri = mongo_uri
# ----> 4     self.client = pymongo.MongoClient(self.mongo_uri)
#       5     self.db_name = db_name
#       6     self.collection_name = collection_name
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\synchronous\mongo_client.py:784, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     780 if timeout is not None:
#     781     timeout = common.validate_timeout_or_none_or_zero(
#     782         keyword_opts.cased_key("connecttimeoutms"), timeout
#     783     )
# --> 784 res = uri_parser.parse_uri(
#     785     entity,
#     786     port,
#     787     validate=True,
#     788     warn=True,
#     789     normalize=False,
#     790     connect_timeout=timeout,
#     791     srv_service_name=srv_service_name,
#     792     srv_max_hosts=srv_max_hosts,
#     793 )
#     794 seeds.update(res["nodelist"])
#     795 username = res["username"] or username
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\uri_parser.py:558, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     556 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     557 dns_resolver = _SrvResolver(fqdn, connect_timeout, srv_service_name, srv_max_hosts)
# --> 558 nodes = dns_resolver.get_hosts()
#     559 dns_options = dns_resolver.get_options()
#     560 if dns_options:
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\srv_resolver.py:141, in _SrvResolver.get_hosts(self)
#     140 def get_hosts(self) -> list[tuple[str, Any]]:
# --> 141     _, nodes = self._get_srv_response_and_hosts(True)
#     142     return nodes
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\srv_resolver.py:120, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#     117 def _get_srv_response_and_hosts(
#     118     self, encapsulate_errors: bool
#     119 ) -> tuple[resolver.Answer, list[tuple[str, Any]]]:
# --> 120     results = self._resolve_uri(encapsulate_errors)
#     122     # Construct address tuples
#     123     nodes = [
#     124         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port)  # type: ignore[attr-defined]
#     125         for res in results
#     126     ]
#
# File d:\Miniconda\envs\machine_translate\lib\site-packages\pymongo\srv_resolver.py:114, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     112         raise
#     113     # Else, raise all errors as ConfigurationError.
# --> 114     raise ConfigurationError(str(exc)) from None
#     115 return results
#
# ConfigurationError: The DNS query name does not exist: _mongodb._tcp.minich-data-repository.gzlkk1s.mongodb.net.

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]
